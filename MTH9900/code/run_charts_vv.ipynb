# %%
import math
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

import pickle

# %%
with open ('euput_rBergomi_results_vv', 'rb') as fp:
    euput_rBergomi_results_vv = pickle.load(fp)
with open ('amput_rBergomi_results_vv', 'rb') as fp:
    amput_rBergomi_results_vv = pickle.load(fp)
with open ('euput_localvol_results_vv', 'rb') as fp:
    euput_localvol_results_vv = pickle.load(fp)
with open ('amput_localvol_results_vv', 'rb') as fp:
    amput_localvol_results_vv = pickle.load(fp)
with open ('Klist_rBergomi_vv', 'rb') as fp:
    Klist_rBergomi_vv = pickle.load(fp)
with open ('Klist_localvol_vv', 'rb') as fp:
    Klist_localvol_vv = pickle.load(fp)

# %%
euput_rBergomi_results_vv = np.array(euput_rBergomi_results_vv)
amput_rBergomi_results_vv = np.array(amput_rBergomi_results_vv)
euput_localvol_results_vv = np.array(euput_localvol_results_vv)
amput_localvol_results_vv = np.array(amput_localvol_results_vv)

# %%
eep_rBergomi_results_vv = amput_rBergomi_results_vv - euput_rBergomi_results_vv
eep_localvol_results_vv = amput_localvol_results_vv - euput_localvol_results_vv
eep_differential_vv = eep_rBergomi_results_vv - eep_localvol_results_vv

# %%
nuList = np.linspace(0.0, 2.0, num=41)[1:]
len(nuList)
# Out:
# 40

# %%
vv_index = 19
print("nu:", nuList[vv_index])
plt.plot(np.log(Klist_localvol_vv), eep_differential_vv[vv_index])
# Out:
# nu: 1.0

# %%
eep_differential_vv.transpose()[10:25].mean(axis=0)
# Out:
# array([ -2.44484900e-05,  -1.95474478e-05,  -1.33922890e-05,
#         -6.63617730e-06,  -6.77072510e-06,   7.04690280e-06,
#          2.33193188e-05,   4.41614301e-05,   6.92643356e-05,
#          9.28997477e-05,   1.13035891e-04,   1.29487401e-04,
#          1.44101603e-04,   1.58978022e-04,   1.90307194e-04,
#          2.26919800e-04,   2.51860178e-04,   2.90313920e-04,
#          2.96009695e-04,   2.98665649e-04,   3.30855431e-04,
#          3.38438868e-04,   3.62365243e-04,   3.76975555e-04,
#          3.89723678e-04,   4.02283031e-04,   4.09226119e-04,
#          4.31226769e-04,   4.29960419e-04,   4.36849337e-04,
#          4.45427326e-04,   4.60635913e-04,   4.72885829e-04,
#          4.76429469e-04,   4.77072942e-04,   4.78168659e-04,
#          4.81726121e-04,   4.69162611e-04,   4.93782615e-04,
#          5.01841151e-04])

# %%
len(eep_differential_vv.mean(axis=1))
# Out:
# 40

# %%
nuList
# Out:
# array([ 0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35,  0.4 ,  0.45,
#         0.5 ,  0.55,  0.6 ,  0.65,  0.7 ,  0.75,  0.8 ,  0.85,  0.9 ,
#         0.95,  1.  ,  1.05,  1.1 ,  1.15,  1.2 ,  1.25,  1.3 ,  1.35,
#         1.4 ,  1.45,  1.5 ,  1.55,  1.6 ,  1.65,  1.7 ,  1.75,  1.8 ,
#         1.85,  1.9 ,  1.95,  2.  ])

# %%
fig, axes = plt.subplots()
#axes.plot(nuList, eep_differential_vv.mean(axis=1), '-ro', mfc='none', markersize=12) 
axes.plot(nuList, 10000*0.02*eep_differential_vv.transpose()[5:25].sum(axis=0), '-ro', mfc='none', markersize=10, linewidth=1.0) 
#axes.plot(nuList[12:38], eep_differential_vv.transpose()[13][12:38], '-ro', mfc='none', markersize=12)
#axes.plot(nuList[12:38], eep_differential_vv.transpose()[14][12:38], '-ro', mfc='none', markersize=12)
#axes.plot(nuList[12:38], eep_differential_vv.transpose()[15][12:38], '-ro', mfc='none', markersize=12)
#axes.plot(nuList[12:38], eep_differential_vv.transpose()[17][12:38], '-ro', mfc='none', markersize=12)
#axes.plot(nuList[12:38], eep_differential_vv.transpose()[20][12:38], '-ro', mfc='none', markersize=12)
#axes.plot(nuList, eep_differential_vv.transpose()[20])
plt.legend(prop={'size':30})
plt.xlabel('Volatility of Volatility (ν)', fontsize=20)
plt.ylabel("$\mathbb{EEP}$ $(10^{-4})$", fontsize=20)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.rcParams["figure.figsize"] = (10,8)

# %%
K_index = 15
print("Log-moneyness:", np.log(Klist_localvol_vv[K_index]))
plt.plot(nuList, eep_differential_vv.transpose()[K_index])
# Out:
# Log-moneyness: 0.0

# %%
np.log(Klist_localvol_vv)
# Out:
# array([-0.3 , -0.28, -0.26, -0.24, -0.22, -0.2 , -0.18, -0.16, -0.14,
#        -0.12, -0.1 , -0.08, -0.06, -0.04, -0.02,  0.  ,  0.02,  0.04,
#         0.06,  0.08,  0.1 ,  0.12,  0.14,  0.16,  0.18,  0.2 ,  0.22,
#         0.24,  0.26,  0.28,  0.3 ])
